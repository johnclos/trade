# %% [markdown]
# From: https://www.youtube.com/watch?v=aeAoVTu66iU

# %%
from yahoo_fin import options
import pandas as pd
import requests
from io import StringIO

# %%
# Define the stock ticker symbol
stock = 'AAPL'

# Add headers to the request
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

# Fetch the options chain page
url = f"https://finance.yahoo.com/quote/{stock}/options?p={stock}"
response = requests.get(url, headers=headers).text

# Wrap the response text with StringIO
try:
    tables = pd.read_html(StringIO(response))
    options_chain = tables[0]  # Typically the first table contains the data
    print(options_chain)
except ValueError:
    print("Could not find any tables. The response might be blocked by Yahoo.")
# Out:
#           Contract Name Last Trade Date (EST)  Strike  Last Price    Bid  \
# 0   AAPL250110C00105000   12/27/2024 11:41 AM   105.0      149.60  135.7
# 1   AAPL250110C00110000   11/29/2024 12:01 PM   110.0      127.73  141.0
# 2   AAPL250110C00115000     1/2/2025 12:37 PM   115.0      127.90  126.3
# 3   AAPL250110C00120000   12/27/2024 11:29 AM   120.0      134.65  121.4
# 4   AAPL250110C00125000   12/27/2024 12:03 PM   125.0      128.65  116.3
# ..                  ...                   ...     ...         ...    ...
# 59  AAPL250110C00310000      1/6/2025 9:30 AM   310.0        0.01    0.0
# 60  AAPL250110C00315000      1/6/2025 9:30 AM   315.0        0.02    0.0
# 61  AAPL250110C00320000      1/6/2025 1:40 PM   320.0        0.01    0.0
# 62  AAPL250110C00325000    12/27/2024 2:16 PM   325.0        0.01    0.0
# 63  AAPL250110C00330000      1/7/2025 9:56 AM   330.0        0.01    0.0
#
#        Ask  Change % Change Volume  Open Interest Implied Volatility
# ...

# %%
tables[0]
# Out:
#           Contract Name Last Trade Date (EST)  Strike  Last Price    Bid  \
# 0   AAPL250110C00105000   12/27/2024 11:41 AM   105.0      149.60  135.7
# 1   AAPL250110C00110000   11/29/2024 12:01 PM   110.0      127.73  141.0
# 2   AAPL250110C00115000     1/2/2025 12:37 PM   115.0      127.90  126.3
# 3   AAPL250110C00120000   12/27/2024 11:29 AM   120.0      134.65  121.4
# 4   AAPL250110C00125000   12/27/2024 12:03 PM   125.0      128.65  116.3
# ..                  ...                   ...     ...         ...    ...
# 59  AAPL250110C00310000      1/6/2025 9:30 AM   310.0        0.01    0.0
# 60  AAPL250110C00315000      1/6/2025 9:30 AM   315.0        0.02    0.0
# 61  AAPL250110C00320000      1/6/2025 1:40 PM   320.0        0.01    0.0
# 62  AAPL250110C00325000    12/27/2024 2:16 PM   325.0        0.01    0.0
# 63  AAPL250110C00330000      1/7/2025 9:56 AM   330.0        0.01    0.0
#
#        Ask  Change % Change Volume  Open Interest Implied Volatility
# ...
