# %%
import pandas as pd

# %%
df = pd.read_json('response_exp_json.json')

# %%
df
# Out:
#                                          OptionExpireDateResponse
# ExpirationDate  [{'day': 3, 'expiryType': 'WEEKLY', 'month': 1...

# %%
df_normalized = pd.json_normalize(df['OptionExpireDateResponse'][0])
# Out:
# C:\Users\jjel0\AppData\Local\Temp\ipykernel_24684\2652158130.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df_normalized = pd.json_normalize(df['OptionExpireDateResponse'][0])

# %%
df_normalized
# Out:
#     day expiryType  month  year
# 0     3     WEEKLY      1  2025
# 1    10     WEEKLY      1  2025
# 2    17    MONTHLY      1  2025
# 3    24     WEEKLY      1  2025
# 4    31     WEEKLY      1  2025
# 5     7     WEEKLY      2  2025
# 6    21    MONTHLY      2  2025
# 7    21    MONTHLY      3  2025
# 8    17    MONTHLY      4  2025
# 9    20    MONTHLY      6  2025
# 10   18    MONTHLY      7  2025
# 11   15    MONTHLY      8  2025
# 12   19    MONTHLY      9  2025
# 13   19    MONTHLY     12  2025
# 14   16    MONTHLY      1  2026
# 15   18    MONTHLY      6  2026
# 16   18    MONTHLY     12  2026
# 17   15    MONTHLY      1  2027

# %%
df2 = pd.read_json('response_json.json')
df2_normalized = pd.json_normalize(df2['OptionChainResponse'][0])
# Out:
# C:\Users\jjel0\AppData\Local\Temp\ipykernel_24684\1432216417.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df2_normalized = pd.json_normalize(df2['OptionChainResponse'][0])

# %%
df2_normalized
# Out:
#     Call.OptionGreeks.currentValue  Call.OptionGreeks.delta  \
# 0                            False             9.998600e-01
# 1                            False             9.996200e-01
# 2                            False             9.995900e-01
# 3                            False             9.995600e-01
# 4                            False             9.995300e-01
# ..                             ...                      ...
# 62                           False             9.700000e-04
# 63                           False             9.200000e-04
# 64                           False             8.800000e-04
# 65                           False             8.300000e-04
# 66                            True            -9.999999e+06
#
#     Call.OptionGreeks.gamma  Call.OptionGreeks.iv  Call.OptionGreeks.rho  \
# 0              1.000000e-05          2.046670e+00           1.365000e-02
# 1              2.000000e-05          2.048200e+00           1.478000e-02
# 2              3.000000e-05          1.945750e+00           1.589000e-02
# 3              3.000000e-05          1.847830e+00           1.701000e-02
# 4              3.000000e-05          1.754040e+00           1.815000e-02
# ..                      ...                   ...                    ...
# 62             2.000000e-04          4.515500e-01           4.000000e-05
# 63             1.800000e-04          4.857500e-01           4.000000e-05
# 64             1.600000e-04          5.191700e-01           4.000000e-05
# 65             1.500000e-04          5.518900e-01           4.000000e-05
# 66            -9.999999e+06         -9.999999e+06          -9.999999e+06
#
#     Call.OptionGreeks.theta  Call.OptionGreeks.vega  Call.adjustedFlag  \
# 0              0.000000e+00            3.300000e-04              False
# 1              0.000000e+00            6.100000e-04              False
# 2              0.000000e+00            6.400000e-04              False
# 3              0.000000e+00            6.800000e-04              False
# 4              0.000000e+00            7.200000e-04              False
# ..                      ...                     ...                ...
# 62            -2.540000e-03            1.210000e-03              False
# 63            -2.590000e-03            1.140000e-03              False
# 64            -2.620000e-03            1.080000e-03              False
# 65            -2.660000e-03            1.030000e-03              False
# 66            -9.999999e+06           -9.999999e+06              False
#
#     Call.ask  Call.askSize  ...  Put.openInterest  Put.optionCategory  \
# 0     157.70            67  ...                56            STANDARD
# 1     152.70            55  ...                 0            STANDARD
# 2     147.65            50  ...                 0            STANDARD
# 3     142.10            50  ...                 0            STANDARD
# 4     137.10            50  ...                 0            STANDARD
# ..       ...           ...  ...               ...                 ...
# 62      0.01            25  ...                 0            STANDARD
# 63      0.01            32  ...                 0            STANDARD
# 64      0.01            32  ...                 0            STANDARD
# 65      0.01            32  ...                 0            STANDARD
# 66      0.01            32  ...                 0            STANDARD
#
#    Put.optionRootSymbol Put.optionType             Put.osiKey  \
# 0                  AAPL            PUT  AAPL--250103P00100000
# 1                  AAPL            PUT  AAPL--250103P00105000
# 2                  AAPL            PUT  AAPL--250103P00110000
# 3                  AAPL            PUT  AAPL--250103P00115000
# 4                  AAPL            PUT  AAPL--250103P00120000
# ..                  ...            ...                    ...
# 62                 AAPL            PUT  AAPL--250103P00310000
# 63                 AAPL            PUT  AAPL--250103P00315000
# 64                 AAPL            PUT  AAPL--250103P00320000
# 65                 AAPL            PUT  AAPL--250103P00325000
# 66                 AAPL            PUT  AAPL--250103P00330000
#
#                                       Put.quoteDetail  Put.strikePrice  \
# 0   https://api.etrade.com/v1/market/quote/AAPL:20...            100.0
# 1   https://api.etrade.com/v1/market/quote/AAPL:20...            105.0
# 2   https://api.etrade.com/v1/market/quote/AAPL:20...            110.0
# 3   https://api.etrade.com/v1/market/quote/AAPL:20...            115.0
# 4   https://api.etrade.com/v1/market/quote/AAPL:20...            120.0
# ..                                                ...              ...
# 62  https://api.etrade.com/v1/market/quote/AAPL:20...            310.0
# 63  https://api.etrade.com/v1/market/quote/AAPL:20...            315.0
# 64  https://api.etrade.com/v1/market/quote/AAPL:20...            320.0
# 65  https://api.etrade.com/v1/market/quote/AAPL:20...            325.0
# 66  https://api.etrade.com/v1/market/quote/AAPL:20...            330.0
#
#    Put.symbol Put.timeStamp Put.volume
# 0        AAPL    1735333199          0
# 1        AAPL    1735333200          0
# 2        AAPL    1735333200          0
# 3        AAPL    1735333200          0
# 4        AAPL    1735333199          0
# ..        ...           ...        ...
# 62       AAPL    1735333199          0
# 63       AAPL    1735333199          0
# 64       AAPL    1735333199          1
# 65       AAPL    1735333199          0
# 66       AAPL    1735333199          1
#
# [67 rows x 52 columns]
