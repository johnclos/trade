# %%
import pandas as pd

# %%
df = pd.read_json('response_exp_json.json')

# %%
df
# Out:
#                                          OptionExpireDateResponse
# ExpirationDate  [{'day': 2, 'expiryType': 'WEEKLY', 'month': 2...

# %%
df_normalized = pd.json_normalize(df['OptionExpireDateResponse'][0])

# %%
df_normalized
# Out:
#     day expiryType  month  year
# 0     2     WEEKLY      2  2024
# 1     9     WEEKLY      2  2024
# 2    16    MONTHLY      2  2024
# 3    23     WEEKLY      2  2024
# 4     1     WEEKLY      3  2024
# 5     8     WEEKLY      3  2024
# 6    15    MONTHLY      3  2024
# 7    19    MONTHLY      4  2024
# 8    17    MONTHLY      5  2024
# 9    21    MONTHLY      6  2024
# 10   19    MONTHLY      7  2024
# 11   20    MONTHLY      9  2024
# 12   20    MONTHLY     12  2024
# 13   17    MONTHLY      1  2025
# 14   20    MONTHLY      6  2025
# 15   19    MONTHLY     12  2025
# 16   16    MONTHLY      1  2026
# 17   18    MONTHLY      6  2026
# 18   18    MONTHLY     12  2026

# %%
df2 = pd.read_json('response_json.json')
df2_normalized = pd.json_normalize(df2['OptionChainResponse'][0])

# %%
df2_normalized
# Out:
#     Call.OptionGreeks.currentValue  Call.OptionGreeks.delta  \
# 0                            False                  1.00000
# 1                            False                  1.00000
# 2                            False                  1.00000
# 3                            False                  1.00000
# 4                            False                  1.00000
# ..                             ...                      ...
# 70                           False                  0.00130
# 71                           False                  0.00113
# 72                           False                  0.00100
# 73                           False                  0.00090
# 74                           False                  0.00082
#
#     Call.OptionGreeks.gamma  Call.OptionGreeks.iv  Call.OptionGreeks.rho  \
# 0                   0.00000               1.87344                0.00013
# 1                   0.00000               1.87344                0.00048
# ...
